# %%
#1. Significant earthquakes since 2150 B.C.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

file_path = "D:/ESE5023_Assignments_12532717/PS2/earthquakes-2025-10-29_21-06-00_+0800.tsv"
Sig_Eqs = pd.read_csv(file_path, delimiter='\t')

# %%
#1.1
deaths_by_country = Sig_Eqs.fillna({'Total Deaths': 0})
top_10_deaths = deaths_by_country.groupby('Country')['Total Deaths'].sum().sort_values(ascending=False).head(10)

print(top_10_deaths)
# Out:
# Country
# CHINA         2106524.0
# TURKEY        1008863.0
# IRAN           761654.0
# SYRIA          487726.0
# ITALY          423280.0
# HAITI          323782.0
# JAPAN          319443.0
# AZERBAIJAN     319251.0
# INDONESIA      282838.0
# ARMENIA        189000.0
# Name: Total Deaths, dtype: float64

# %%
#1.2
filtered_eqs = Sig_Eqs.dropna(subset=['Mag', 'Year'])
mag_gt_6 = filtered_eqs[filtered_eqs['Mag'] > 6.0]
yearly_counts = mag_gt_6.groupby('Year').size()

plt.figure(figsize=(12, 6))
yearly_counts.plot(kind='line')
plt.title('Total Number of Significant Earthquakes (Mag > 6.0) per Year')
plt.xlabel('Year')
plt.ylabel('Number of Earthquakes')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
#1.3
def CountEq_LargestEq(df, country_name):
    country_df = df[(df['Country'] == country_name) & (df['Mag'].notna())].copy()
    
    total_count = len(country_df)
    
    if total_count == 0:
        return (0, None)
    
    largest_eq_row = country_df.loc[country_df['Mag'].idxmax()]
    
    year = largest_eq_row.get('Year')
    
    return (total_count, year)

all_countries = Sig_Eqs['Country'].dropna().unique()

results = []
for country in all_countries:
    count, date = CountEq_LargestEq(Sig_Eqs, country)
    if count > 0:
        results.append({
            'Country': country,
            'TotalEarthquakes': count,
            'LargestEarthquakeYear': date
        })

results_df = pd.DataFrame(results)
results_df_sorted = results_df.sort_values(by='TotalEarthquakes', ascending=False)

print(results_df_sorted)
# Out:
#                                           Country  TotalEarthquakes  \
# 14                                          CHINA               592
# 33                                          JAPAN               361
# 70                                      INDONESIA               340
# 7                                            IRAN               263
# 54                                            USA               229
# 9                                          TURKEY               224
# 3                                          GREECE               181
# 50                                           PERU               157
# 58                                          CHILE               148
# 15                                         RUSSIA               148
# 51                                         MEXICO               144
# 68                                    PHILIPPINES               142
# 5                                           ITALY               105
# 88                               PAPUA NEW GUINEA                99
# 74                                         TAIWAN                98
# 8                                           INDIA                86
# 64                                       COLOMBIA                68
# 98                                    NEW ZEALAND                66
# 109                               SOLOMON ISLANDS                62
# 22                                    AFGHANISTAN                62
# 61                                        ECUADOR                58
# 104                                       VANUATU                57
# 20                                       PAKISTAN                44
# 45                                        ALGERIA                39
# 63                                      GUATEMALA                37
# 16                                        ALBANIA                35
# 53                                      VENEZUELA                30
# 66                                     COSTA RICA                29
# 49                                MYANMAR (BURMA)                29
# 113                                    TAJIKISTAN                28
# 73                                      NICARAGUA                28
# 80                                      ARGENTINA                28
# 105                                 NEW CALEDONIA                28
# 65                                    EL SALVADOR                25
# 103                                     AUSTRALIA                24
# 83                                  USA TERRITORY                23
# 111                KERMADEC ISLANDS (NEW ZEALAND)                23
# 102                                         TONGA                21
# 21                                    SOUTH KOREA                21
# 69                                         PANAMA                20
# 41                                          NEPAL                19
# 75                                         CANADA                17
# 99                                           FIJI                17
# 86                                     BANGLADESH                15
# 17                                        GEORGIA                15
# 28                                         FRANCE                15
# 11                                          SPAIN                15
# 10                                     KYRGYZSTAN                15
# 26                                     AZERBAIJAN                14
# 31                                       SLOVENIA                14
# 93                                   SOUTH AFRICA                13
# 57                                        ROMANIA                13
# 23                                        UKRAINE                12
# 37                                     UZBEKISTAN                12
# 18                                       BULGARIA                12
# 43                                        CROATIA                12
# 59                              AZORES (PORTUGAL)                11
# 2                                    TURKMENISTAN                11
# 81                                          HAITI                11
# 76                                         BRAZIL                10
# 48                                         SERBIA                10
# 60                                       HONDURAS                10
# 46                             BOSNIA-HERZEGOVINA                 9
# 29                                     KAZAKHSTAN                 9
# 4                                          ISRAEL                 9
# 67                                        BOLIVIA                 8
# 71                                       ETHIOPIA                 8
# 13                                       PORTUGAL                 8
# 24                                      MACEDONIA                 8
# 119                                         SAMOA                 8
# 142                                        POLAND                 8
# 115                                      TANZANIA                 8
# 55                             DOMINICAN REPUBLIC                 8
# 36                                        ARMENIA                 8
# 35                                             UK                 7
# 95                                          CONGO                 7
# 78                                           CUBA                 7
# 12                                          EGYPT                 7
# 124  SOUTH GEORGIA AND THE SOUTH SANDWICH ISLANDS                 7
# 110                                      MONGOLIA                 6
# 121                                       VIETNAM                 6
# 92                            TRINIDAD AND TOBAGO                 6
# 85                                 ATLANTIC OCEAN                 6
# 30                                    NORTH KOREA                 6
# 38                                        ICELAND                 6
# 126                                    ANTARCTICA                 6
# 138                                        RWANDA                 5
# 139                                        BHUTAN                 5
# 97                                     GUADELOUPE                 5
# 0                                          JORDAN                 5
# 87                                        HUNGARY                 5
# 56                                        GERMANY                 5
# 62                                     MONTENEGRO                 5
# 72                                          GHANA                 5
# 39                                    SWITZERLAND                 4
# 101                                   SOUTH SUDAN                 4
# 42                                        MOROCCO                 4
# 6                                         LEBANON                 4
# 1                                           SYRIA                 4
# 131                                        MALAWI                 4
# 117                                        UGANDA                 4
# 84                                        ERITREA                 4
# 44                                        AUSTRIA                 3
# 123                                  INDIAN OCEAN                 3
# 32                                           IRAQ                 3
# 27                                       THAILAND                 3
# 40                                          YEMEN                 3
# 134                                   NETHERLANDS                 3
# 19                                         CYPRUS                 3
# 128                                      MALAYSIA                 3
# 116                    MICRONESIA, FED. STATES OF                 3
# 141                                  SAUDI ARABIA                 3
# 143                                    MOZAMBIQUE                 3
# 77                                        JAMAICA                 3
# 82                                     MARTINIQUE                 3
# 108                                   SOLOMON SEA                 2
# 106                                 COTE D'IVOIRE                 2
# 25                                        TUNISIA                 2
# 137                                          LAOS                 2
# 52                                           OMAN                 2
# 122                                         KENYA                 2
# 79                            ANTIGUA AND BARBUDA                 2
# 125                                 PACIFIC OCEAN                 2
# 123                 1928.0
# 32                  1864.0
# 27                  2014.0
# 40                  1982.0
# 134                 1992.0
# 19                  1953.0
# 128                 1976.0
# 116                 1911.0
# 141                 2009.0
# 143                 2006.0
# 77                  1899.0
# 82                  1906.0
# 108                 1895.0
# 106                 1879.0
# 25                  1957.0
# 137                 2007.0
# 52                  1570.0
# 122                 1928.0
# 79                  1690.0
# 125                 1932.0
# 140                 2004.0
# 145                 2017.0
# 133                 1991.0
# 146                 2017.0
# 135                 1993.0
# 144                 2008.0
# 136                 1993.0
# 132                 1989.0
# 90                  1788.0
# 130                 1983.0
# 129                 1983.0
# 127                 1974.0
# 34                  1963.0
# 120                 1921.0
# 91                  1795.0
# 118                 1914.0
# 114                 1945.0
# 112                 1905.0
# 47                  2004.0
# 107                 1892.0
# 100                 1848.0
# 96                  1983.0
# 94                  1819.0
# 89                  1885.0
# 147                 2018.0

# %%
#2. Wind speed in Shenzhen from 2010 to 2020
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

plt.rcParams['font.family'] = 'Arial'
plt.rcParams['svg.fonttype'] = 'none'


file_path = '2281305.csv'
df = pd.read_csv(file_path, low_memory=False)
data = df[['DATE', 'WND']].copy()
split_cols = data['WND'].str.split(',', expand=True)
data['WND_SPEED_RAW'] = split_cols[3]
data['WND_QUALITY_RAW'] = split_cols[4]

data['DATETIME'] = pd.to_datetime(data['DATE'], errors='coerce')
data['WND_SPEED'] = pd.to_numeric(data['WND_SPEED_RAW'], errors='coerce')

valid_quality_codes = ['0', '1', '4', '5', '9']
missing_speed_code = 9999
data['WND_SPEED'] = data['WND_SPEED'].replace(missing_speed_code, np.nan)

df_filtered = data[
    (data['WND_QUALITY_RAW'].isin(valid_quality_codes)) &
    (data['WND_SPEED'].notna()) &
    (data['DATETIME'].notna())
].copy()


df_filtered['WIND_MPS'] = df_filtered['WND_SPEED'] / 10.0
df_filtered = df_filtered.set_index('DATETIME')


with warnings.catch_warnings():
    warnings.simplefilter("ignore", FutureWarning)
    monthly_avg_wind = df_filtered['WIND_MPS'].resample('M').mean()


x = np.arange(len(monthly_avg_wind))
y = monthly_avg_wind.values
mask = ~np.isnan(y)
x_fit = x[mask]
y_fit = y[mask]

trend_stats = stats.linregress(x_fit, y_fit)
m, b, p_value = trend_stats.slope, trend_stats.intercept, trend_stats.pvalue

trendline = (m * x) + b
trend_series = pd.Series(trendline, index=monthly_avg_wind.index)

# 格式化字符串
expression_str = f"y = {m:.5f}x + {b:.3f}"
p_value_str = f"p-value: {p_value:.6f}"


plt.figure(figsize=(14, 7))
ax = plt.gca() 

monthly_avg_wind.plot(kind='line', label='Monthly Avg Wind Speed', ax=ax)

trend_series.plot(
    kind='line',
    color='red',
    linestyle='--',
    label='Long-term Trend',
    ax=ax
)


plt.title('Shenzhen (BaoAn Airport) Monthly Averaged Wind Speed (2010-2020)')
plt.xlabel('Year')
plt.ylabel('Average Wind Speed (m/s)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

plt.text(
    0.05, 0.95, 
    text_to_plot,
    transform=ax.transAxes,
    fontsize=12,
    verticalalignment='top',
    bbox=dict(boxstyle='round,pad=0.5', facecolor='white', alpha=0.8)
)
# Out:
# Text(0.05, 0.95, 'y = 0.00482x + 3.077\np-value: 0.000018')

# %%
#3.Explore a data set
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


FILE_PATH = r"ICESat2_lake_height.csv"
# 使用 pandas 读取 CSV 文件
df = pd.read_csv(FILE_PATH)
print(f"行数 (Rows): {df.shape[0]}")
print(f"列数 (Columns): {df.shape[1]}")
# 显示数据的前5行
print(df.head())
# 显示所有列的名称及其数据类型
print(df.info())
# Out:
# 行数 (Rows): 227386
# 列数 (Columns): 27
#    id   Latitude   Longitude      Area     Type  Oct2018     Nov2018  \
# 0   1  77.912613  -23.634773  0.666206  Natural      NaN         NaN
# 1   2  77.892250  -23.822008  0.108693  Natural      NaN  928.545349
# 2   3  77.868866  -20.779461  0.315888  Natural      NaN         NaN
# 3   4  77.843330 -110.950310  0.598154  Natural      NaN   -3.412109
# 4   5  77.831947  -20.891270  0.355333  Natural      NaN         NaN
#
#       Dec2018     Jan2019   Feb2019  Mar2019     Apr2019     May2019  \
# 0  775.671814         NaN       NaN      NaN         NaN         NaN
# 1         NaN  928.693787       NaN      NaN         NaN  928.926147
# 2         NaN         NaN       NaN      NaN   90.351400         NaN
# 3   -3.328942         NaN -3.199217      NaN         NaN   -3.154937
# 4         NaN         NaN       NaN      NaN  171.377846  171.282623
#
#     Jun2019     Jul2019  Aug2019   Sep2019     Oct2019     Nov2019   Dec2019  \
# 0       NaN         NaN      NaN       NaN         NaN  772.795502       NaN
# 1       NaN         NaN      NaN       NaN         NaN         NaN       NaN
# 2       NaN   89.984301      NaN       NaN   89.826809         NaN       NaN
# 3 -3.167234         NaN      NaN -3.637697         NaN         NaN -3.448276
# 4       NaN  170.826790      NaN       NaN  171.002904  170.972336       NaN
#
#    Jan2020     Feb2020   Mar2020    Apr2020  May2020   Jun2020  Jul2020
# 0      NaN         NaN       NaN        NaN      NaN       NaN      NaN
# 1      NaN  927.205017       NaN        NaN      NaN       NaN      NaN
# 2      NaN         NaN       NaN  90.550261      NaN       NaN      NaN
# 3      NaN   -3.323550 -3.277608        NaN      NaN -3.353647      NaN
# 4      NaN         NaN       NaN        NaN      NaN       NaN      NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227386 entries, 0 to 227385
# Data columns (total 27 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         227386 non-null  int64
#  1   Latitude   227386 non-null  float64
#  2   Longitude  227386 non-null  float64
#  3   Area       227386 non-null  float64
#  4   Type       227386 non-null  object
#  5   Oct2018    14424 non-null   float64
#  6   Nov2018    32001 non-null   float64
#  7   Dec2018    34378 non-null   float64
#  8   Jan2019    29536 non-null   float64
#  9   Feb2019    40091 non-null   float64
#  10  Mar2019    40315 non-null   float64
#  11  Apr2019    48875 non-null   float64
#  12  May2019    38372 non-null   float64
#  13  Jun2019    31083 non-null   float64
#  14  Jul2019    6653 non-null    float64
#  15  Aug2019    32561 non-null   float64
#  16  Sep2019    29770 non-null   float64
#  17  Oct2019    28490 non-null   float64
# 191046   184.567415   185.127782   185.498128   185.436180   185.711409
# 193605   419.347108   418.628769   420.761242   417.469236   417.501212
# 207673   146.242404   146.464620   146.830445   146.284453   146.723931
# 208715   153.697062   152.630447   152.578082   152.962059   152.102126
# 209353   295.275295   294.580648   295.113062   295.345543   295.296617
# 211174   139.967337   139.756570   140.132211   139.841298   139.858553
# 213100    39.087934    38.432475    38.682730    38.400271    38.213163
# 213962   138.167054   138.270116   138.240468   138.373275   138.497357
# 222417  1118.674483  1119.621662  1118.641270  1118.865569  1119.145359
# 223311   760.442688   759.220551   757.425524   757.720882   756.672691
# 223518   756.694946   754.950356   754.710419   755.086945   756.692390
# 224013   456.576067          NaN          NaN   458.686787   461.083163
#
#             Apr2020      May2020      Jun2020      Jul2020
# 95540    144.823421   143.574838   143.143247   143.478931
# 142792   127.772008   128.684613   127.195734          NaN
# 149420    22.742567    21.146817    22.509172    20.937564
# 191046   186.486258   187.740797   184.656055   186.586935
# 193605   418.777261   418.502194   418.323616   421.978538
# 207673   146.848602   146.224627   145.824520   146.793604
# 208715   152.477985   151.432947   153.586899   152.257014
# 209353   294.826168   294.723184   295.540588   295.753118
# 211174   139.871767   140.427980   140.399023   140.159123
# 213100    38.580314    39.035517    38.971305    38.186845
# 213962   138.621411   138.636884   138.724669   138.646328
# 222417  1119.248507  1119.684840  1120.151181  1118.920803
# 223311   758.500885          NaN   758.674835          NaN
# 223518   756.825104          NaN   758.014491          NaN
# 224013   456.031593   459.894432   459.941512   457.976588
#
# [15 rows x 27 columns]

# %%
#3.1 
id_cols = ['id', 'Latitude', 'Longitude', 'Area', 'Type']
month_cols = df_lakes.columns.drop(id_cols)

df_cleaned = df_lakes.copy()
df_cleaned[month_cols] = df_cleaned[month_cols].apply(pd.to_numeric, errors='coerce')

null_before = df_cleaned[month_cols].isnull().sum().sum()
print(f"转换为数字格式后，所有月份列中总共有 {null_before} 个 NaN 值。")

# 1. 执行线性插值 
df_cleaned[month_cols] = df_cleaned[month_cols].interpolate(method='linear', axis=1)
print("线性插值完成。")

# 2. 填补边缘 
df_cleaned[month_cols] = df_cleaned[month_cols].bfill(axis=1)


print("边缘填充完成。")

null_after = df_cleaned[month_cols].isnull().sum().sum()
print(f"插值和边缘填充后，所有月份列中剩余 {null_after} 个 NaN 值。")

print("插值后数据预览 (df_cleaned):")
print(df_cleaned.head())
# Out:
# 转换为数字格式后，所有月份列中总共有 25 个 NaN 值。
# 线性插值完成。
# 边缘填充完成。
# 插值和边缘填充后，所有月份列中剩余 0 个 NaN 值。
#
# --- 3.1 (宽格式) 插值完成 ---
# 插值后数据预览 (df_cleaned):
#             id   Latitude   Longitude          Area       Type     Oct2018  \
# 95540    95541  66.170349 -123.098793  22622.509073    Natural  142.182180
# 142792  142793  61.623337 -114.189430  26039.404469    Natural  126.583547
# 149420  149421  60.752140   31.949997  17116.098144  Reservoir   20.877350
# 191046  191047  53.086105  -98.453865  24827.936811  Reservoir  184.391208
# 193605  193606  52.548405  106.370277  31951.020835  Reservoir  421.951141
#
#            Nov2018     Dec2018     Jan2019     Feb2019     Mar2019  \
# 95540   143.606663  142.518844  143.242034  143.835225  143.567022
# 142792  127.078623  127.541004  127.211344  127.163485  126.985538
# 149420   19.895657   19.942883   20.431718   21.033176   19.634016
# 191046  184.288714  184.278557  185.391982  187.286412  186.097685
# 193605  418.897403  419.534525  419.740347  417.782043  417.859833
#
#            Apr2019     May2019     Jun2019     Jul2019     Aug2019  \
# 95540   143.540918  143.718724  142.948381  143.356049  143.763718
# 142792  126.825382  126.817694  127.043706  126.247117  127.421238
# 149420   21.487126   20.627504   20.313654   20.277207   20.247953
# 191046  184.908958  189.195905  185.168013  186.473242  187.778471
# 193605  420.148443  421.285627  417.424483  420.437762  423.451042
#
#            Sep2019     Oct2019     Nov2019     Dec2019     Jan2020  \
# 95540   143.518135  142.839623  142.367170  143.590946  143.734313
# 142792  127.344134  127.108449  127.883572  128.722741  127.283182
# 149420   23.034639   20.076752   20.009856   19.534496   21.897986
# 191046  183.776223  184.775945  184.567415  185.127782  185.498128
# 193605  419.351915  420.813239  419.347108  418.628769  420.761242
#
#            Feb2020     Mar2020     Apr2020     May2020     Jun2020     Jul2020
# 95540   143.383112  143.370858  144.823421  143.574838  143.143247  143.478931
# 142792  127.117013  127.262662  127.772008  128.684613  127.195734  127.195734
# 149420   21.590687   20.121696   22.742567   21.146817   22.509172   20.937564
# 191046  185.436180  185.711409  186.486258  187.740797  184.656055  186.586935
# 193605  417.469236  417.501212  418.777261  418.502194  418.323616  421.978538

# %%
month_cols = df_cleaned.columns[5:]

time_data = pd.to_datetime(month_cols, format='%b%Y')

df_to_plot = df_cleaned.head(5)
num_plots = len(df_to_plot)
print(f"准备为 {num_plots} 个湖泊绘制图表...")

fig, axes = plt.subplots(nrows=num_plots, ncols=1, figsize=(12, num_plots * 4))
if num_plots == 1:
    axes = [axes]

for ax, (index, lake_row) in zip(axes, df_to_plot.iterrows()):
    
    
    lake_id = lake_row['id']
    height_data = lake_row[month_cols]
    

    ax.plot(time_data, height_data, marker='o', linestyle='-')
    
    ax.set_title(f'Lake Height Time Series (ID: {lake_id})')
    ax.set_xlabel('Date')
    ax.set_ylabel('Height')
    ax.grid(True)


plt.tight_layout()
plt.show()
# Out:
# 准备为 5 个湖泊绘制图表...

# %%
info_cols = df_cleaned.iloc[:, :5]
month_cols_names = df_cleaned.columns[5:]
month_data_cleaned = df_cleaned[month_cols_names]
month_data_original = df_lakes[month_cols_names].apply(pd.to_numeric, errors='coerce')

stats_df = pd.DataFrame(index=df_cleaned.index)

stats_df['Max'] = month_data_cleaned.max(axis=1)
stats_df['Min'] = month_data_cleaned.min(axis=1)
stats_df['Mean'] = month_data_cleaned.mean(axis=1)
stats_df['Median'] = month_data_cleaned.median(axis=1)
stats_df['Std_Dev'] = month_data_cleaned.std(axis=1)


stats_df['Valid_Count'] = month_data_original.count(axis=1)

def calculate_slope(row_with_nans):
    # 将行数据转为 numpy 数组
    y = row_with_nans.values
    x = np.arange(len(y))
    
    # 创建一个 "遮罩" (mask)，只选择非NaN的数据
    mask = ~np.isnan(y)
    
    # 如果有效数据点少于2个，无法计算斜率
    if np.sum(mask) < 2:
        return np.nan
        
    x_masked = x[mask]
    y_masked = y[mask]
    
    # np.polyfit(x, y, 1) 会返回 [斜率, 截距]
    # 我们只取 [0] (即斜率)
    slope, intercept = np.polyfit(x_masked, y_masked, 1)
    
    return slope


stats_df['Avg_Month_Change'] = month_data_original.apply(calculate_slope, axis=1)
final_output = pd.concat([info_cols, stats_df], axis=1)
print(final_output)
# Out:
#             id   Latitude   Longitude           Area       Type          Max  \
# 95540    95541  66.170349 -123.098793   22622.509073    Natural   144.823421
# 142792  142793  61.623337 -114.189430   26039.404469    Natural   128.722741
# 149420  149421  60.752140   31.949997   17116.098144  Reservoir    23.034639
# 191046  191047  53.086105  -98.453865   24827.936811  Reservoir   189.195905
# 193605  193606  52.548405  106.370277   31951.020835  Reservoir   423.451042
# 207673  207674  47.537960  -87.010521   70418.379664  Reservoir   147.434461
# 208715  208716  46.965714  -91.424416   11451.130547  Reservoir   154.541555
# 209353  209354  46.598183   76.393738   16544.870734    Natural   295.824089
# 211174  211175  45.478054  -83.532387  116096.987982  Reservoir   140.626729
# 213100  213101  43.720364  -77.652008   19230.172780  Reservoir    39.354362
# 213962  213963  42.009071  -81.920372   21434.902813    Natural   138.961023
# 222417  222418  -1.181953   33.516998   62549.175393  Reservoir  1120.151181
# 223311  223312  -5.638087   29.667446   20303.874173    Natural   760.488525
# 223518  223519  -8.145950   30.798113   12254.016935    Natural   758.014491
# 224013  224014 -13.890139   34.932316   27466.892302    Natural   461.083163
#
#                 Min         Mean       Median   Std_Dev  Valid_Count  \
# 95540    142.182180   143.368380   143.498533  0.562945           21
# 142792   126.247117   127.294933   127.195734  0.577032           21
# 149420    19.534496    20.835022    20.529611  1.006288           22
# 191046   183.776223   185.710103   185.414081  1.371056           20
# 193605   417.424483   419.543954   419.349512  1.657880           21
# 207673   145.804186   146.493255   146.505760  0.428066           22
# 208715   151.432947   152.795354   152.791133  0.714511           21
# 209353   294.276296   295.131347   295.237609  0.427453           21
# 211174   139.480956   140.062314   139.948342  0.310825           22
# 213100    36.993446    38.499145    38.471362  0.626550           21
# 213962   137.947904   138.424009   138.413090  0.259146           22
# 222417  1117.689011  1118.634144  1118.691611  0.691110           21
# 223311   756.672691   758.147079   757.846375  1.062593           15
# 223518   754.710419   756.305563   756.355385  0.877181           18
# 224013   455.817261   458.308071   458.156919  1.292420           17
#
#         Avg_Month_Change
# 95540           0.027258
# 142792          0.046761
# 149420          0.063488
# 191046          0.042735
# 193605         -0.030518
# 207673          0.007528
# 208715         -0.009785
# 209353          0.005998
# 211174          0.008148
# 213100          0.039676
# 213962          0.020512
# 222417          0.076114
# 223311         -0.014642
# 223518          0.012172
# 224013          0.035992
